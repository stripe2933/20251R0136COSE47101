# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# alldata는 https://data.kma.go.kr/data/grnd/selectAwsRltmList.do?pgmNo=56에서 수집한 방재기상관측자료에서 2022년 1월 1일 00시 ~ 2024년 12월 31일 23시까지의 전체 지점 관측 데이터를 사용하였다. 데이터 크기가 매우 커서 업로드하지 않고 링크 첨부.

# %%
file = '/content/alldata.csv'
raw = pd.read_csv(file, encoding='cp949')
# Out:
# <ipython-input-29-41d71bf07874>:2: DtypeWarning: Columns (0,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw = pd.read_csv(file, encoding='cp949')

# %%
raw.head(5)
# Out:
#    지점     지점명                일시 기온(°C) 풍향(deg) 풍속(m/s) 강수량(mm) 습도(%)
# 0  12  안면도(감)  2022-01-01 00:00   -4.5    34.0     2.6     0.0  59.0
# 1  12  안면도(감)  2022-01-01 01:00   -4.6    37.8     2.4     0.0  58.0
# 2  12  안면도(감)  2022-01-01 02:00   -5.0    62.6     2.7     0.0  65.0
# 3  12  안면도(감)  2022-01-01 03:00   -5.0    68.4     2.9     0.0  54.0
# 4  12  안면도(감)  2022-01-01 04:00   -4.9    65.6     2.7     0.0  51.0

# %%
raw.tail(5)
# Out:
#            지점  지점명                일시 기온(°C) 풍향(deg) 풍속(m/s) 강수량(mm) 습도(%)
# 16418974  996   화동  2024-12-31 20:00   -0.8   266.5     3.8     0.0  38.0
# 16418975  996   화동  2024-12-31 21:00   -1.6   262.5     5.2     0.0  46.0
# 16418976  996   화동  2024-12-31 22:00   -2.4   263.6     3.9     0.0  55.0
# 16418977  996   화동  2024-12-31 23:00   -3.7   281.2     2.5     0.0  60.0
# 16418978      NaN               NaN    NaN     NaN     NaN     NaN   NaN

# %%
df = raw.copy()
df.head(3)
# Out:
#    지점     지점명                일시 기온(°C) 풍향(deg) 풍속(m/s) 강수량(mm) 습도(%)
# 0  12  안면도(감)  2022-01-01 00:00   -4.5    34.0     2.6     0.0  59.0
# 1  12  안면도(감)  2022-01-01 01:00   -4.6    37.8     2.4     0.0  58.0
# 2  12  안면도(감)  2022-01-01 02:00   -5.0    62.6     2.7     0.0  65.0

# %%
# 여러 데이터 파일을 합치는 과정에서 중복되는 헤더 행을 삭제하는 과정
rows_to_remove = (df.iloc[:, 0] == '지점')
cleaned_df = df[~rows_to_remove]
cleaned_df.head(3)
# Out:
#    지점     지점명                일시 기온(°C) 풍향(deg) 풍속(m/s) 강수량(mm) 습도(%)
# 0  12  안면도(감)  2022-01-01 00:00   -4.5    34.0     2.6     0.0  59.0
# 1  12  안면도(감)  2022-01-01 01:00   -4.6    37.8     2.4     0.0  58.0
# 2  12  안면도(감)  2022-01-01 02:00   -5.0    62.6     2.7     0.0  65.0

# %%
print(f"총 데이터 행 수 (원본, 헤더 제외): {len(df)}")
print(f"삭제된 행 수 (첫 번째 열 값이 '지점'인 행): {rows_to_remove.sum()}")
print(f"총 데이터 행 수 (정리 후): {len(cleaned_df)}")
# Out:
# 총 데이터 행 수 (원본, 헤더 제외): 16418979
# 삭제된 행 수 (첫 번째 열 값이 '지점'인 행): 6
# 총 데이터 행 수 (정리 후): 16418973

# %%
cleaned_df.to_csv('cleaned_alldata.csv', index=False, encoding='cp949')

# %% [markdown]
# 깔끔한 파일로 다시 시작하도록 재설정 + 마지막 NaN 행 삭제한 final_alldata.csv 파일 사용

# %%
file = '/content/final_alldata.csv'
df = pd.read_csv(file, encoding='cp949')

# %%
df
# Out:
#            지점     지점명                일시  기온(°C)  풍향(deg)  풍속(m/s)  강수량(mm)  \
# 0          12  안면도(감)  2022-01-01 00:00    -4.5     34.0      2.6      0.0
# 1          12  안면도(감)  2022-01-01 01:00    -4.6     37.8      2.4      0.0
# 2          12  안면도(감)  2022-01-01 02:00    -5.0     62.6      2.7      0.0
# 3          12  안면도(감)  2022-01-01 03:00    -5.0     68.4      2.9      0.0
# 4          12  안면도(감)  2022-01-01 04:00    -4.9     65.6      2.7      0.0
# ...       ...     ...               ...     ...      ...      ...      ...
# 16418967  996      화동  2024-12-31 19:00    -0.5    268.2      3.1      0.0
# 16418968  996      화동  2024-12-31 20:00    -0.8    266.5      3.8      0.0
# 16418969  996      화동  2024-12-31 21:00    -1.6    262.5      5.2      0.0
# 16418970  996      화동  2024-12-31 22:00    -2.4    263.6      3.9      0.0
# 16418971  996      화동  2024-12-31 23:00    -3.7    281.2      2.5      0.0
#
#           습도(%)
# 0          59.0
# 1          58.0
# 2          65.0
# 3          54.0
# 4          51.0
# ...         ...
# 16418967   38.0
# 16418968   38.0
# 16418969   46.0
# 16418970   55.0
# 16418971   60.0
#
# [16418972 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16418972 entries, 0 to 16418971
# Data columns (total 8 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   지점       int64
#  1   지점명      object
#  2   일시       object
#  3   기온(°C)   float64
#  4   풍향(deg)  float64
#  5   풍속(m/s)  float64
#  6   강수량(mm)  float64
#  7   습도(%)    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 1002.1+ MB

# %%
df['지점'].nunique()
# Out:
# 552

# %% [markdown]
# 관측지점의 위치를 나타내는 메타데이터 파일 불러오기

# %%
loc_file = './data/META_LOCATION.csv'
loc_df = pd.read_csv(loc_file, encoding='cp949')

# %%
loc_df
# Out:
#        지점         시작일         종료일     지점명             지점주소          관리관서  \
# 0      12  2007-11-30         NaN  안면도(감)     충청남도 태안군 승언리           NaN
# 1      96  2020-10-23         NaN      독도     경상북도 울릉군 독도리   울릉도기상대(115)
# 2      96  2009-10-27  2020-10-23      독도     경상북도 울릉군 독도리   울릉도기상대(115)
# 3     116  2023-10-21         NaN   관악(레)      경기도 과천시 중앙동           NaN
# 4     116  2010-08-06  2023-10-21   관악(레)      경기도 과천시 중앙동           NaN
# ...   ...         ...         ...     ...              ...           ...
# 2456  992  2021-11-10         NaN      하빈    대구광역시 달성군 현내리     대구(구 143)
# 2457  993  2024-04-06         NaN    제주금악  제주특별자치도 제주시 금악리  제주지방기상청(184)
# 2458  994  2022-05-02         NaN      심포              NaN    전주기상대(146)
# 2459  995  2023-12-19         NaN      오천   경상북도 포항시남구 항사리    포항기상대(138)
# 2460  996  2023-12-19         NaN      화동     경상북도 상주시 평산리     대구(구 143)
#
#            위도        경도  노장해발고도(m)  기압계(관측장비지상높이(m))  기온계(관측장비지상높이(m))  \
# 0     36.5333  126.3167      60.00               NaN               NaN
# 1     37.2395  131.8698      99.08               NaN               NaN
# 2     37.2395  131.8698      96.15               NaN               NaN
# 3     37.4453  126.9640     624.82               NaN               NaN
# 4     37.4453  126.9640     624.82               NaN               NaN
# ...       ...       ...        ...               ...               ...
# 2456  35.9062  128.4464      35.50               NaN               NaN
# 2457  33.3423  126.3099     279.00               NaN               NaN
# 2458  35.8545  126.6421       3.00               NaN               NaN
# 2459  35.9286  129.3822      80.32               NaN               NaN
# 2460  36.3721  127.8949     360.46               NaN               NaN
#
#       풍속계(관측장비지상높이(m))  강우계(관측장비지상높이(m))
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 2456               NaN               NaN
# 2457               NaN               NaN
# 2458               NaN               NaN
# 2459               NaN               NaN
# 2460               NaN               NaN
#
# [2461 rows x 13 columns]

# %%
loc_df['지점'].nunique()
# Out:
# 572

# %%
#지점 중복되는 행 삭제
loc_df = loc_df.drop_duplicates(subset=['지점'], keep='first')
loc_df.head(5)
# Out:
#     지점         시작일         종료일     지점명             지점주소          관리관서  \
# 0   12  2007-11-30         NaN  안면도(감)     충청남도 태안군 승언리           NaN
# 1   96  2020-10-23         NaN      독도     경상북도 울릉군 독도리   울릉도기상대(115)
# 3  116  2023-10-21         NaN   관악(레)      경기도 과천시 중앙동           NaN
# 6  144  1993-03-16  2011-12-09   군산(레)     전라북도 군산시 성덕리    군산기상대(140)
# 7  160  2020-10-23         NaN   부산(레)  부산광역시 서구 서대신동3가  부산지방기상청(159)
#
#         위도        경도  노장해발고도(m)  기압계(관측장비지상높이(m))  기온계(관측장비지상높이(m))  \
# 0  36.5333  126.3167      60.00               NaN               NaN
# 1  37.2395  131.8698      99.08               NaN               NaN
# 3  37.4453  126.9640     624.82               NaN               NaN
# 6  36.0123  126.7834     198.61               NaN               NaN
# 7  35.1188  129.0000     512.00               NaN               NaN
#
#    풍속계(관측장비지상높이(m))  강우계(관측장비지상높이(m))
# 0               NaN               NaN
# 1               NaN               NaN
# 3               NaN               NaN
# 6               NaN               NaN
# 7               NaN               NaN

# %%
len(loc_df)
# Out:
# 572

# %%
#불필요한 열 삭제하고 지점정보, 기록된 일자, 위도, 경도만 남김
columns_to_keep = ['지점', '시작일', '종료일', '지점명', '위도', '경도']
all_columns = loc_df.columns

columns_to_drop = [col for col in all_columns if col not in columns_to_keep]
loc_df.drop(columns=columns_to_drop, inplace=True)
# Out:
# C:\Users\apffg\AppData\Local\Temp\ipykernel_9076\740618183.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loc_df.drop(columns=columns_to_drop, inplace=True)

# %%
loc_df
# Out:
#        지점         시작일         종료일     지점명       위도        경도
# 0      12  2007-11-30         NaN  안면도(감)  36.5333  126.3167
# 1      96  2020-10-23         NaN      독도  37.2395  131.8698
# 3     116  2023-10-21         NaN   관악(레)  37.4453  126.9640
# 6     144  1993-03-16  2011-12-09   군산(레)  36.0123  126.7834
# 7     160  2020-10-23         NaN   부산(레)  35.1188  129.0000
# ...   ...         ...         ...     ...      ...       ...
# 2456  992  2021-11-10         NaN      하빈  35.9062  128.4464
# 2457  993  2024-04-06         NaN    제주금악  33.3423  126.3099
# 2458  994  2022-05-02         NaN      심포  35.8545  126.6421
# 2459  995  2023-12-19         NaN      오천  35.9286  129.3822
# 2460  996  2023-12-19         NaN      화동  36.3721  127.8949
#
# [572 rows x 6 columns]

# %%
loc_df.to_csv('meta-loc-edited.csv', index=False, encoding='cp949')

# %% [markdown]
# 기상데이터파일 df의 결측값 찾기

# %%
columns_to_check = ['기온(°C)', '풍향(deg)', '풍속(m/s)', '강수량(mm)', '습도(%)']
for column in columns_to_check:
    if column in df.columns:
        # 해당 열의 NaN 값 개수를 계산합니다.
        nan_count = df[column].isnull().sum()
        print(f"'{column}': {nan_count}개")
    else:
        print(f"경고: '{column}' 열이 데이터에 존재하지 않습니다.")
# Out:
# '기온(°C)': 41642개
# '풍향(deg)': 142816개
# '풍속(m/s)': 122439개
# '강수량(mm)': 207056개
# '습도(%)': 308852개

# %%
#결측값 행 확인
rows_with_nan = df[df.isnull().any(axis=1)]
if not rows_with_nan.empty:
    print(rows_with_nan)
    print(f"\n총 {len(rows_with_nan)}개의 행에서 결측값이 발견되었습니다.")
else:
    print("데이터프레임에 결측값이 포함된 행이 없습니다.")
# Out:
#            지점     지점명                일시  기온(°C)  풍향(deg)  풍속(m/s)  강수량(mm)  \
# 817        12  안면도(감)  2022-02-04 01:00     NaN     48.2      1.0      NaN
# 818        12  안면도(감)  2022-02-04 02:00     NaN     53.8      1.5      NaN
# 819        12  안면도(감)  2022-02-04 03:00     NaN     74.1      1.4      NaN
# 820        12  안면도(감)  2022-02-04 04:00     NaN    110.3      1.3      NaN
# 821        12  안면도(감)  2022-02-04 05:00     NaN     55.5      2.2      NaN
# ...       ...     ...               ...     ...      ...      ...      ...
# 16417800  996      화동  2024-11-13 04:00     5.6      NaN      NaN      0.0
# 16417963  996      화동  2024-11-19 23:00     2.0      NaN      NaN      0.0
# 16417964  996      화동  2024-11-20 00:00     1.6      NaN      NaN      0.0
# 16418806  996      화동  2024-12-25 02:00    -3.8      NaN      NaN      0.0
# 16418807  996      화동  2024-12-25 03:00    -4.1      NaN      NaN      0.0
#
#           습도(%)
# 817        57.0
# 818        56.0
# 819        56.0
# 820        62.0
# 821        85.0
# ...         ...
# 16417800   91.0
# 16417963   90.0
# 16417964   91.0
# 16418806   79.0
# 16418807   82.0
#
# [648176 rows x 8 columns]
#
# 총 648176개의 행에서 결측값이 발견되었습니다.

# %% [markdown]
# 결측값에 임의로 직전 데이터의 정보를 대체 기록

# %%
columns_to_fill = ['기온(°C)', '풍향(deg)', '풍속(m/s)', '강수량(mm)', '습도(%)']

print("지정된 열의 결측값을 직전 데이터로 채우는 중입니다...")
for col in columns_to_fill:
    if col in df.columns:
        df[col] = df[col].ffill()
        print(f"'{col}' 열 결측값 채우기 완료.")
    else:
        print(f"경고: '{col}' 열이 데이터에 존재하지 않습니다. 이 열은 건너뛰었습니다.")
# Out:
# 지정된 열의 결측값을 직전 데이터로 채우는 중입니다...
# '기온(°C)' 열 결측값 채우기 완료.
# '풍향(deg)' 열 결측값 채우기 완료.
# '풍속(m/s)' 열 결측값 채우기 완료.
# '강수량(mm)' 열 결측값 채우기 완료.
# '습도(%)' 열 결측값 채우기 완료.

# %%
#결측값 행 확인
rows_with_nan = df[df.isnull().any(axis=1)]
if not rows_with_nan.empty:
    print(rows_with_nan)
    print(f"\n총 {len(rows_with_nan)}개의 행에서 결측값이 발견되었습니다.")
else:
    print("데이터프레임에 결측값이 포함된 행이 없습니다.")
# Out:
# 데이터프레임에 결측값이 포함된 행이 없습니다.

# %% [markdown]
# 실효습도 계산하기
# * 기존 데이터의 습도(%)는 상대습도를 의미.
# * **실효습도** : 화재 예방의 목적으로 수일 전부터의 상대습도에 경과 시간에 따른 가중치를 주어서 산출한 목재 등의 건조도를 나타내는 지수.
# 실효습도가 50% 이하가 되면 큰 화재로 번질 위험성이 높아집니다.
# * He = (1−r)×[H0dt + r H1dt + r2 H2dt+r3 H3dt + r4H4dt]
#  - r = 0.7
#  - He : 실효습도
#  - H0d : 당일의 상대습도
#  - H1d : 1일 전의 상대습도
#  - H2d : 2일 전의 상대습도
#  - H3d : 3일 전의 상대습도
#  - H4d : 4일 전의 상대습도

# %%
r = 0.7 #실효습도 계산 상수
def calculate_effective_humidity(row, df, r) :
  current_index = row.name

  H0d = row['습도(%)']

  past_humidities = []
  for i in range(1, 5) :
    prev_index = current_index - i
    if prev_index >= 0 :
      past_humidities.append(df.loc[prev_index, '습도(%)'])
    else :
      pass

    sum_of_humidities = H0d
    for i, h_prev in enumerate(past_humidities) :
      sum_of_humidities += (r ** (i + 1)) * h_prev

    He = (1 - r) * sum_of_humidities

    return He

# %%
df['실효습도'] = df.apply(lambda row: calculate_effective_humidity(row, df, r), axis=1)

# %%
df
# Out:
#            지점     지점명                일시  기온(°C)  풍향(deg)  풍속(m/s)  강수량(mm)  \
# 0          12  안면도(감)  2022-01-01 00:00    -4.5     34.0      2.6      0.0
# 1          12  안면도(감)  2022-01-01 01:00    -4.6     37.8      2.4      0.0
# 2          12  안면도(감)  2022-01-01 02:00    -5.0     62.6      2.7      0.0
# 3          12  안면도(감)  2022-01-01 03:00    -5.0     68.4      2.9      0.0
# 4          12  안면도(감)  2022-01-01 04:00    -4.9     65.6      2.7      0.0
# ...       ...     ...               ...     ...      ...      ...      ...
# 16418967  996      화동  2024-12-31 19:00    -0.5    268.2      3.1      0.0
# 16418968  996      화동  2024-12-31 20:00    -0.8    266.5      3.8      0.0
# 16418969  996      화동  2024-12-31 21:00    -1.6    262.5      5.2      0.0
# 16418970  996      화동  2024-12-31 22:00    -2.4    263.6      3.9      0.0
# 16418971  996      화동  2024-12-31 23:00    -3.7    281.2      2.5      0.0
#
#           습도(%)   실효습도
# 0          59.0  17.70
# 1          58.0  29.79
# 2          65.0  31.68
# 3          54.0  29.85
# 4          51.0  26.64
# ...         ...    ...
# 16418967   38.0  18.96
# 16418968   38.0  19.38
# 16418969   46.0  21.78
# 16418970   55.0  26.16
# 16418971   60.0  29.55
#
# [16418972 rows x 9 columns]

# %%
df['지점'].nunique()
# Out:
# 552

# %%
df.to_csv('whetherDataEH.csv', index=False, encoding='cp949')
